# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv("heart.csv")
df.head()
# Out:
#    age  sex  pain type   BP  cholestrol  fbs  resting ecg  max heart rate  \
# 0   70    1          4  130         322    0            2             109
# 1   67    0          3  115         564    0            2             160
# 2   57    1          2  124         261    0            0             141
# 3   64    1          4  128         263    0            0             105
# 4   74    0          2  120         269    0            2             121
#
#    exercise angina  ST depression  ST slope  flouroscopy coloured  thal  \
# 0                0            2.4         2                     3     3
# 1                0            1.6         2                     0     7
# 2                0            0.3         1                     0     7
# 3                1            0.2         2                     1     7
# 4                1            0.2         1                     1     3
#
#    heart disease  Unnamed: 14
# 0              2          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   age                   270 non-null    int64
#  1   sex                   270 non-null    int64
#  2   pain type             270 non-null    int64
#  3   BP                    270 non-null    int64
#  4   cholestrol            270 non-null    int64
#  5   fbs                   270 non-null    int64
#  6   resting ecg           270 non-null    int64
#  7   max heart rate        270 non-null    int64
#  8   exercise angina       270 non-null    int64
#  9   ST depression         270 non-null    float64
#  10  ST slope              270 non-null    int64
#  11  flouroscopy coloured  270 non-null    int64
#  12  thal                  270 non-null    int64
#  13  heart disease         270 non-null    int64
#  14  Unnamed: 14           0 non-null      float64
# ...

# %%
df.describe([0.25,0.5,0.75,0.90,0.99])
# Out:
#               age         sex   pain type          BP  cholestrol         fbs  \
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean    54.433333    0.677778    3.174074  131.344444  249.659259    0.148148
# std      9.109067    0.468195    0.950090   17.861608   51.686237    0.355906
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  213.000000    0.000000
# 50%     55.000000    1.000000    3.000000  130.000000  245.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  280.000000    0.000000
# 90%     66.000000    1.000000    4.000000  152.000000  309.000000    1.000000
# 99%     71.930000    1.000000    4.000000  180.000000  407.620000    1.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#        resting ecg  max heart rate  exercise angina  ST depression  \
# ...

# %%
sns.pairplot(df)

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    age  sex  pain type   BP  cholestrol  fbs  resting ecg  max heart rate  \
# 0   70    1          4  130         322    0            2             109
# 1   67    0          3  115         564    0            2             160
# 2   57    1          2  124         261    0            0             141
# 3   64    1          4  128         263    0            0             105
# 4   74    0          2  120         269    0            2             121
#
#    exercise angina  ST depression  ST slope  flouroscopy coloured  thal  \
# 0                0            2.4         2                     3     3
# 1                0            1.6         2                     0     7
# 2                0            0.3         1                     0     7
# 3                1            0.2         2                     1     7
# 4                1            0.2         1                     1     3
#
#    heart disease  Unnamed: 14
# 0              2          NaN
# ...

# %%
column_to_drop=['Unnamed: 14']
df.drop(columns=column_to_drop, inplace=True)

# %%
df.head()
# Out:
#    age  sex  pain type   BP  cholestrol  fbs  resting ecg  max heart rate  \
# 0   70    1          4  130         322    0            2             109
# 1   67    0          3  115         564    0            2             160
# 2   57    1          2  124         261    0            0             141
# 3   64    1          4  128         263    0            0             105
# 4   74    0          2  120         269    0            2             121
#
#    exercise angina  ST depression  ST slope  flouroscopy coloured  thal  \
# 0                0            2.4         2                     3     3
# 1                0            1.6         2                     0     7
# 2                0            0.3         1                     0     7
# 3                1            0.2         2                     1     7
# 4                1            0.2         1                     1     3
#
#    heart disease
# 0              2
# 1              1
# 2              2
# ...

# %%
plt.figure(figsize=(20, 20))
plt.subplot(2,3,1)
sns.boxplot(x = 'age', y = 'heart disease', data = df)
plt.subplot(2,3,2)
sns.boxplot(x = 'sex', y = 'heart disease', data = df)
plt.subplot(2,3,3)
sns.boxplot(x = 'pain type', y = 'heart disease', data = df)
plt.subplot(2,3,4)
sns.boxplot(x = 'cholestrol', y = 'heart disease', data = df)
plt.subplot(2,3,5)
sns.boxplot(x = 'max heart rate', y = 'heart disease', data = df)
plt.subplot(2,3,6)
sns.boxplot(x = 'ST depression', y = 'heart disease', data = df)
plt.show()

# %%
plt.figure(figsize=(20, 20))
sns.boxplot(df)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(df['cholestrol'])
# Out:
# <Axes: ylabel='cholestrol'>

# %%
res=df["cholestrol"].median()
df.loc[df['cholestrol']>350,"cholestrol"]=res
df
# Out:
#      age  sex  pain type   BP  cholestrol  fbs  resting ecg  max heart rate  \
# 0     70    1          4  130         322    0            2             109
# 1     67    0          3  115         245    0            2             160
# 2     57    1          2  124         261    0            0             141
# 3     64    1          4  128         263    0            0             105
# 4     74    0          2  120         269    0            2             121
# ..   ...  ...        ...  ...         ...  ...          ...             ...
# 265   52    1          3  172         199    1            0             162
# 266   44    1          2  120         263    0            0             173
# 267   56    0          2  140         294    0            2             153
# 268   57    1          4  140         192    0            0             148
# 269   67    1          4  160         286    0            2             108
#
# ...

# %%
sns.boxplot(df['cholestrol'])
# Out:
# <Axes: ylabel='cholestrol'>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
dt_default = DecisionTreeClassifier()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 dt_default = DecisionTreeClassifier()
#
# NameError: name 'DecisionTreeClassifier' is not defined
