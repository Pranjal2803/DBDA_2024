# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("students.csv")
print(df)
df.describe()
# Out:
#          Name  Marks  Attendance  Study Hours  Social Media hours  \
# 0      aditya     85          98            8                   2
# 1     yadnyik      7          90            2                   9
# 2     shefali     75          94            6                   3
# 3    utkarsha     89          97            5                   1
# 4        anup     55          89            3                   7
# 5     shreyas     62          75           10                   4
# 6      ashish     42          82            2                  12
# 7        teja     36          45            1                  13
# 8       purva     74          33            6                   2
# 9    jayashri     70          25           12                   2
# 10    santosh     25          81            1                  10
# 11    ashwini     55          25            4                   8
# 12      priya     46          10            5                   5
# ...

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(20, 12))
plt.subplot(2,3,1)
sns.boxplot(x='Marks',y='CGPA', data =df)
plt.subplot(2,3,2)
sns.boxplot(x='Study Hours',y='CGPA', data =df)
plt.subplot(2,3,2)
sns.boxplot(x='Social Media hours', y='CGPA',data =df)
plt.subplot(2,3,2)
plt.show()

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
x=(df[['Marks','Study Hours','Social Media hours']])
y=df["CGPA"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=.30)

# %%
len(x_train)
# Out:
# 14

# %%
len(x_test)
# Out:
# 6

# %%
x_train.shape
# Out:
# (14, 3)

# %%
len(y_train)
# Out:
# 14

# %%
len(y_test)
# Out:
# 6

# %%
y_train.shape
# Out:
# (14,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
yhat=lr.predict(x_test)

# %%
print(yhat)
# Out:
# [8.33364553 5.72390697 6.98460476 1.68594933 1.68962916 1.43694112]

# %%
lr.score(x_test,y_test)
# Out:
# 0.9103421849237452

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,yhat))
# Out:
# 0.9103421849237452

# %%
from sklearn.linear_model import Ridge
ridge=Ridge(alpha=0.05,normalize=True).fit(x,y)
# Out:
# C:\Users\dbda14\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(

# %%
ridge.score(x,y)
# Out:
# 0.9581605450188507

# %%
sns.
